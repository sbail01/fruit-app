# %% [markdown]
# make sure these are installed before trying to run :3

# %%
pip install transformers torch Pillow numpy
# Out:
# ...
#      ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/134.8 kB ? eta -:--:--
#      ----------- ------------------------- 41.0/134.8 kB 393.8 kB/s eta 0:00:01
#      -----------------------------------  133.1/134.8 kB 983.0 kB/s eta 0:00:01
#      ------------------------------------ 134.8/134.8 kB 883.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.8 MB 10.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/8.8 MB 11.0 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.8 MB 11.1 MB/s eta 0:00:01
# ...
