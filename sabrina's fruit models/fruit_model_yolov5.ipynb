# %% [markdown]
# Install and set up YOLOv5 environment

# %% [markdown]
# get data from: https://drive.google.com/drive/folders/1b992eorR6xL3ojCkIxl_fhI8OnDUi74C?usp=sharing will be updated with properly labeled once i get through all of the images

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-297-gd07d0cf6 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/78.2 GB disk)

# %%
# %cd /content/yolov5
# !cp ../drive/MyDrive/best.pt best.pt
# Out:
# /content/yolov5
# cp: cannot stat '../drive/MyDrive/best.pt': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%writefile /content/drive/MyDrive/sab/fruit-data/data.yaml
# train: /content/drive/MyDrive/sab/fruit-data/train/images
# val: /content/drive/MyDrive/sab/fruit-data/valid/images
# test: /content/drive/MyDrive/sab/fruit-data/test/images
#
# nc: 11
# names: ['apple', 'avocado', 'blueberry', 'capsicum', 'cherry', 'kiwi', 'mango', 'orange', 'rockmelon', 'strawberry', 'wheat']
# Out:
# Overwriting /content/drive/MyDrive/sab/fruit-data/data.yaml

# %%
# import torch

# model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 v7.0-297-gd07d0cf6 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 303MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Path to your hyp.scratch.yaml file
file_path = '/content/drive/MyDrive/sab/fruit-data/hyp.yaml'

# Open and read the file
with open(file_path, 'r') as file:
    contents = file.read()

# Print the contents
print(contents)
# Out:
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# warmup_bias_lr: 0.1
# box: 0.05
# cls: 0.5
# cls_pw: 1.0
# obj: 1.0
# obj_pw: 1.0
# iou_t: 0.2
# anchor_t: 4.0
# fl_gamma: 0.0
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0

# %%
# !python train.py --img 640 --batch 16 --epochs 5 --data /content/drive/MyDrive/sab/fruit-data/data.yaml --weights /content/drive/MyDrive/sab/fruit-data/best.pt --cfg yolov5s.yaml --cache
# !python train.py --img 640 --batch 16 --epochs 10 --data /content/drive/MyDrive/sab/fruit-data/data.yaml --weights /content/drive/MyDrive/sab/fruit-data/best.pt



# !cp "runs/train/exp/weights/best.pt" "/content/drive/MyDrive/sab/fruit-data"
# !rsync -av "runs/train/exp/" "/content/drive/MyDrive/sab/fruit-data"
# Out:
# 2024-04-11 07:26:49.420522: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 07:26:49.420584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 07:26:49.421918: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/sab/fruit-data/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/sab/fruit-data/test/images
# Out:
# detect: weights=['/content/drive/MyDrive/sab/fruit-data/best.pt'], source=/content/drive/MyDrive/sab/fruit-data/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-297-gd07d0cf6 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/431 /content/drive/.shortcut-targets-by-id/1b992eorR6xL3ojCkIxl_fhI8OnDUi74C/fruit-data/test/images/0000315_bing-cherry_jpg.rf.3febcf21b60898e578bbe268308644c7.jpg: 640x640 15 apples, 9.8ms
# ...
